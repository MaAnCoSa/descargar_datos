# %% [markdown]
# <center>
# <p><img src="https://mcd.unison.mx/wp-content/themes/awaken/img/logo_mcd.png" width="150">
# </p>
#
#
#
# # Curso *Ingeniería de Características*
#
# ### Descargando datos
#
#
# <p> Julio Waissman Vilanova </p>
#
#
# <a target="_blank" href="https://colab.research.google.com/github/mcd-unison/ing-caract/blob/main/ejemplos/integracion/python/descarga_datos.ipynb"><img src="https://i.ibb.co/2P3SLwK/colab.png"  style="padding-bottom:5px;" />Ejecuta en Google Colab</a>
#
# </center>

# %% [markdown]
# # 1. Descargando datos a la fuerza bruta
#
# Vamos a ver primero como ir descargando datos y luego como lidiar con diferentes formatos. Es muy importante que, si los datos los vamos a cargar por única vez, descargar el conjunto de datos, tal como se encuentran, esto es `raw data`.
#
# Vamos primero cargando las bibliotecas necesarias:

# %%
import os  # Para manejo de archivos y directorios
import urllib.request # Una forma estandard de descargar datos
# import requests # Otra forma no de las librerías de uso comun

import datetime # Fecha de descarga
import pandas as pd # Solo para ver el archivo descargado
import zipfile # Descompresión de archivos

# %% [markdown]
# Es importante saber en donde nos encontramos y crear los subdirectorios necesarios para guardar los datos de manera ordenada. Tambien es importante evitar cargar datos que ya han sido descargados anteriormente.

# %%
# pwd
print(os.getcwd())

#  Estos son los datos que vamos a descargar y donde vamos a guardarlos
desaparecidos_RNPDNO_url = "http://www.datamx.io/dataset/fdd2ca20-ee70-4a31-9bdf-823f3c1307a2/resource/d352810c-a22e-4d72-bb3b-33c742c799dd/download/desaparecidos3ago.zip"
desaparecidos_RNPDNO_archivo = "desaparecidosRNPDNO.zip"
desaparecidos_corte_nacional_url = "http://www.datamx.io/dataset/fdd2ca20-ee70-4a31-9bdf-823f3c1307a2/resource/4865e244-cf59-4d39-b863-96ed7f45cc70/download/nacional.json"
desaparecidos_corte_nacional_archivo = "desaparecidos_nacional.json"
subdir = "./data/"
# Out:
# /content

# %%
if not os.path.exists(desaparecidos_RNPDNO_archivo):
    if not os.path.exists(subdir):
        os.makedirs(subdir)
    urllib.request.urlretrieve(desaparecidos_RNPDNO_url, subdir + desaparecidos_RNPDNO_archivo)
    with zipfile.ZipFile(subdir + desaparecidos_RNPDNO_archivo, "r") as zip_ref:
        zip_ref.extractall(subdir)

    urllib.request.urlretrieve(desaparecidos_corte_nacional_url, subdir + desaparecidos_corte_nacional_archivo)

    with open(subdir + "info.txt", 'w') as f:
        f.write("Archivos sobre personas desaparecidas\n")
        info = """
        Datos de desaparecidos, corte nacional y desagregación a nivel estatal,
        por edad, por sexo, por nacionalidad, por año de desaparición y por mes
        de desaparición para los últimos 12 meses.

        Los datos se obtuvieron del RNPDNO con fecha de 03 de agosto de 2021
        (la base de datos no se ha actualizado últimamente)

        """
        f.write(info + '\n')
        f.write("Descargado el " + datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S") + "\n")
        f.write("Desde: " + desaparecidos_RNPDNO_url + "\n")
        f.write("Nombre: " + desaparecidos_RNPDNO_archivo + "\n")
        f.write("Agregados nacionales descargados desde: " + desaparecidos_corte_nacional_url + "\n")
        f.write("Nombre: " + desaparecidos_corte_nacional_archivo + "\n")

# %% [markdown]
# # 2. Archivos en formato `json`
#
# Los archivos en formato json son posiblemente los más utilizados actualmente para transferir información por internet, ya que se usa en prácticamente todas las REST API. Como acabamos de ver es normal tener que enfrentarse con archivos `json` pésimamente o nada documentados, por lo que es necesario saber como tratarlos.
#
# Vamos a ver como se hace eso utilizando la bibloteca de `json`y la de `pandas`. Para `pandas`les recomiendo, si no lo conocen, de darle una vuelta a [la documentación y los tutoriales](https://pandas.pydata.org/docs/) que está muy bien hecha. O a el [curso básico de Kaggle](https://www.kaggle.com/learn/pandas).
#
# Sobre `json`, posiblemente [la página con la especificación](https://www.json.org/json-en.html) sea más que suficiente.
#
# Vamos a hacer un ejemplito sencillo y carismático revisando los repositorios de [github](https://github.com) y les voy a dejar que exploren los `json` de los archivos de personas desaparecidas.

# %%
import pandas as pd # Esto es como una segunda piel
import json # Una forma estandar de leer archivos json

archivo_url = "https://api.github.com/users/google/repos"
archivo_nombre = "repos-google.json"
subdir = "./data/"

if not os.path.exists(subdir + archivo_nombre):
    if not os.path.exists(subdir):
        os.makedirs(subdir)
    urllib.request.urlretrieve(archivo_url, subdir + archivo_nombre)

# %% [markdown]
# Vamos primero a ver como le hacemos con `pandas`

# %%
df_repos = pd.read_json(subdir + archivo_nombre)

df_repos.head()
# Out:
#           id                           node_id                 name  \
# 0  460600860                      R_kgDOG3Q2HA             .allstar
# 1  170908616  MDEwOlJlcG9zaXRvcnkxNzA5MDg2MTY=              .github
# 2  143044068  MDEwOlJlcG9zaXRvcnkxNDMwNDQwNjg=      0x0g-2018-badge
# 3  424674738                      R_kgDOGVAFsg  aarch64-esr-decoder
# 4  487987687                      R_kgDOHRYZ5w       aarch64-paging
#
#                     full_name  private  \
# 0             google/.allstar    False
# 1              google/.github    False
# 2      google/0x0g-2018-badge    False
# 3  google/aarch64-esr-decoder    False
# 4       google/aarch64-paging    False
#
#                                                owner  \
# 0  {'login': 'google', 'id': 1342004, 'node_id': ...
# 1  {'login': 'google', 'id': 1342004, 'node_id': ...
# 2  {'login': 'google', 'id': 1342004, 'node_id': ...
# 3  {'login': 'google', 'id': 1342004, 'node_id': ...
# 4  {'login': 'google', 'id': 1342004, 'node_id': ...
#
#                                         html_url  \
# 0             https://github.com/google/.allstar
# 1              https://github.com/google/.github
# 2      https://github.com/google/0x0g-2018-badge
# 3  https://github.com/google/aarch64-esr-decoder
# 4       https://github.com/google/aarch64-paging
#
#                                          description   fork  \
# 0                                               None  False
# 1            default configuration for @google repos  False
# 2                                               None  False
# 3  A utility for decoding aarch64 ESR register va...  False
# 4  A Rust library to manipulate AArch64 VMSA EL1 ...  False
#
#                                                  url  ...  \
# 0       https://api.github.com/repos/google/.allstar  ...
# 1        https://api.github.com/repos/google/.github  ...
# 2  https://api.github.com/repos/google/0x0g-2018-...  ...
# 3  https://api.github.com/repos/google/aarch64-es...  ...
# 4  https://api.github.com/repos/google/aarch64-pa...  ...
#
#                                              license allow_forking  \
# 0  {'key': 'apache-2.0', 'name': 'Apache License ...          True
# 1                                               None          True
# 2  {'key': 'apache-2.0', 'name': 'Apache License ...          True
# 3  {'key': 'apache-2.0', 'name': 'Apache License ...          True
# 4  {'key': 'other', 'name': 'Other', 'spdx_id': '...          True
#
#   is_template web_commit_signoff_required  \
# 0       False                       False
# 1       False                       False
# 2       False                       False
# 3       False                       False
# 4       False                       False
#
#                                          topics visibility forks open_issues  \
# 0                                            []     public     2           0
# 1                                            []     public   253          15
# 2                                            []     public     5           0
# 3                                     [aarch64]     public    16           3
# 4  [aarch64, pagetable, rust, rust-crate, vmsa]     public     9           1
#
#   watchers default_branch
# 0        6           main
# 1       90         master
# 2       18         master
# 3       67           main
# 4       26           main
#
# [5 rows x 79 columns]

# %%
df_repos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 79 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   id                           30 non-null     int64
#  1   node_id                      30 non-null     object
#  2   name                         30 non-null     object
#  3   full_name                    30 non-null     object
#  4   private                      30 non-null     bool
#  5   owner                        30 non-null     object
#  6   html_url                     30 non-null     object
#  7   description                  13 non-null     object
#  8   fork                         30 non-null     bool
#  9   url                          30 non-null     object
#  10  forks_url                    30 non-null     object
#  11  keys_url                     30 non-null     object
#  12  collaborators_url            30 non-null     object
#  13  teams_url                    30 non-null     object
#  14  hooks_url                    30 non-null     object
#  15  issue_events_url             30 non-null     object
#  16  events_url                   30 non-null     object
#  17  assignees_url                30 non-null     object
#  18  branches_url                 30 non-null     object
#  19  tags_url                     30 non-null     object
#  20  blobs_url                    30 non-null     object
#  21  git_tags_url                 30 non-null     object
#  22  git_refs_url                 30 non-null     object
#  23  trees_url                    30 non-null     object
#  24  statuses_url                 30 non-null     object
#  25  languages_url                30 non-null     object
#  26  stargazers_url               30 non-null     object
#  27  contributors_url             30 non-null     object
#  28  subscribers_url              30 non-null     object
#  29  subscription_url             30 non-null     object
#  30  commits_url                  30 non-null     object
#  31  git_commits_url              30 non-null     object
#  32  comments_url                 30 non-null     object
#  33  issue_comment_url            30 non-null     object
#  34  contents_url                 30 non-null     object
#  35  compare_url                  30 non-null     object
#  36  merges_url                   30 non-null     object
#  37  archive_url                  30 non-null     object
#  38  downloads_url                30 non-null     object
#  39  issues_url                   30 non-null     object
#  40  pulls_url                    30 non-null     object
#  41  milestones_url               30 non-null     object
#  42  notifications_url            30 non-null     object
#  43  labels_url                   30 non-null     object
#  44  releases_url                 30 non-null     object
#  45  deployments_url              30 non-null     object
#  46  created_at                   30 non-null     datetime64[ns, UTC]
#  47  updated_at                   30 non-null     datetime64[ns, UTC]
#  48  pushed_at                    30 non-null     datetime64[ns, UTC]
#  49  git_url                      30 non-null     object
#  50  ssh_url                      30 non-null     object
#  51  clone_url                    30 non-null     object
#  52  svn_url                      30 non-null     object
#  53  homepage                     13 non-null     object
#  54  size                         30 non-null     int64
#  55  stargazers_count             30 non-null     int64
#  56  watchers_count               30 non-null     int64
#  57  language                     27 non-null     object
#  58  has_issues                   30 non-null     bool
#  59  has_projects                 30 non-null     bool
#  60  has_downloads                30 non-null     bool
#  61  has_wiki                     30 non-null     bool
#  62  has_pages                    30 non-null     bool
#  63  has_discussions              30 non-null     bool
#  64  forks_count                  30 non-null     int64
#  65  mirror_url                   0 non-null      float64
#  66  archived                     30 non-null     bool
#  67  disabled                     30 non-null     bool
#  68  open_issues_count            30 non-null     int64
#  69  license                      29 non-null     object
#  70  allow_forking                30 non-null     bool
#  71  is_template                  30 non-null     bool
#  72  web_commit_signoff_required  30 non-null     bool
#  73  topics                       30 non-null     object
#  74  visibility                   30 non-null     object
#  75  forks                        30 non-null     int64
#  76  open_issues                  30 non-null     int64
#  77  watchers                     30 non-null     int64
#  78  default_branch               30 non-null     object
# dtypes: bool(13), datetime64[ns, UTC](3), float64(1), int64(9), object(53)
# memory usage: 16.0+ KB

# %% [markdown]
# y ahora como le hacemos con la biblioteca de `json`

# %%
with open(subdir + archivo_nombre, 'r') as fp:
    repos = json.load(fp)

print(f"\nNúmero de entradas: {len(repos)}")
print(f"\nNombre de los atributos: { ', '.join(repos[0].keys())}")
print(f"\nAtributos de 'owner': {', '.join(repos[0]['owner'].keys())}")
# Out:
# Número de entradas: 30
#
# Nombre de los atributos: id, node_id, name, full_name, private, owner, html_url, description, fork, url, forks_url, keys_url, collaborators_url, teams_url, hooks_url, issue_events_url, events_url, assignees_url, branches_url, tags_url, blobs_url, git_tags_url, git_refs_url, trees_url, statuses_url, languages_url, stargazers_url, contributors_url, subscribers_url, subscription_url, commits_url, git_commits_url, comments_url, issue_comment_url, contents_url, compare_url, merges_url, archive_url, downloads_url, issues_url, pulls_url, milestones_url, notifications_url, labels_url, releases_url, deployments_url, created_at, updated_at, pushed_at, git_url, ssh_url, clone_url, svn_url, homepage, size, stargazers_count, watchers_count, language, has_issues, has_projects, has_downloads, has_wiki, has_pages, has_discussions, forks_count, mirror_url, archived, disabled, open_issues_count, license, allow_forking, is_template, web_commit_signoff_required, topics, visibility, forks, open_issues, watchers, default_branch
#
# Atributos de 'owner': login, id, node_id, avatar_url, gravatar_id, url, html_url, followers_url, following_url, gists_url, starred_url, subscriptions_url, organizations_url, repos_url, events_url, received_events_url, type, site_admin

# %% [markdown]
# ### Ejercicio
#
# Utiliza los archivos `json` descargados con el detalle a nivel estatal, y genera unos 3 `DataFrame` con información sobre personas desaparecidas dependiendo de diferentes características.

# %%
# 1er DataFrame: Cantidad de Desaparecidos por Estado.

# Podemos ver que el primer JSON de la categoría espacial se trata de los totales
# de desaparecidos, por sexo y por estado.

with open("data/datos_procesados/estados/0.json") as f:
  desap_json = json.load(f)

desap_df = pd.read_json(json.dumps(desap_json["espacial"], indent=4))

desap_df
# Out:
# <ipython-input-174-6bf55edac8c2>:9: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   desap_df = pd.read_json(json.dumps(desap_json["espacial"], indent=4))
#                      Hombre  Indeterminado  Mujer
# AGUASCALIENTES         1848              3   2537
# BAJA CALIFORNIA        2065              5   1938
# BAJA CALIFORNIA SUR     582              2    214
# CAMPECHE                243              0    504
# CHIAPAS                1344              0   2060
# CHIHUAHUA              8012              4   4306
# CIUDAD DE MEXICO       5628            167   4695
# COAHUILA               2964              2   1054
# COLIMA                 2047              2   1710
# DURANGO                1610              1   1220
# ESTADO DE MEXICO      18070             17  21669
# GUANAJUATO             7118            228   7744
# GUERRERO               3663              8   1436
# HIDALGO                1264              5   1614
# JALISCO               15845             16   4582
# MICHOACAN              4664              7   1899
# MORELOS                1557              2   1611
# NAYARIT                1221              4    315
# NUEVO LEON             5600              1   3413
# OAXACA                 1465              8   2150
# PUEBLA                 4328              5   5020
# QUERETARO              1135              1   1084
# QUINTANA ROO            880              0   1187
# SAN LUIS POTOSI         654              2    636
# SE DESCONOCE            625             74    293
# SINALOA                8184              4   2466
# SONORA                 4345              7   2223
# TABASCO                 319              1    499
# TAMAULIPAS            11624             19   5387
# TLAXCALA                116              1    114
# VERACRUZ               4719             17   2075
# YUCATAN                2622              1   4209
# ZACATECAS              2263              0    978

# %%
# Veamos entonces los totales para solo el estado de Sonora.

desap_df.loc["SONORA"]
# Out:
# Hombre           4345
# Indeterminado       7
# Mujer            2223
# Name: SONORA, dtype: int64

# %%
# Podemos encontrar los totales más delimitados por municipios del estado de Sonora
# en el JSON 26.

with open("data/datos_procesados/estados/26.json") as f:
  desap_json = json.load(f)

desap_sonora_df = pd.read_json(json.dumps(desap_json["espacial"], indent=4))

desap_sonora_df
# Out:
# <ipython-input-176-47549f6b511f>:7: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   desap_sonora_df = pd.read_json(json.dumps(desap_json["espacial"], indent=4))
#                  Hombres  Indeterminado  Mujeres
# ACONCHI                3              0        3
# AGUA PRIETA          296              0      174
# ALAMOS                28              0       12
# ALTAR                 54              0       12
# ARIVECHI               1              0        0
# ...                  ...            ...      ...
# TUBUTAMA               0              0        1
# URES                   5              0        1
# VILLA HIDALGO          1              0        0
# VILLA PESQUEIRA        0              0        1
# YÉCORA                 4              0        2
#
# [64 rows x 3 columns]

# %%
# Delimitemos ahora a los totales de solo el municipio de Hermosillo.

desap_sonora_df.loc["HERMOSILLO"]
# Out:
# Hombres          970
# Indeterminado      0
# Mujeres          644
# Name: HERMOSILLO, dtype: int64

# %%
# Finalmente, veamos en qué posición se encuentra Hermosillo en cuanto a cantidad
# de desaparecidos, comparado con los demás municipios.

#HOMBRES
desap_hombres_hmo = desap_sonora_df.sort_values(by='Hombres', ascending=False, na_position='first')
desap_hombres_hmo['pos'] = range(1, len(desap_hombres_hmo) + 1)

hombres_pos_hmo = desap_hombres_hmo.loc["HERMOSILLO"].loc["pos"]

#MUJERES
desap_mujeres_hmo = desap_sonora_df.sort_values(by='Mujeres', ascending=False, na_position='first')
desap_mujeres_hmo['pos'] = range(1, len(desap_mujeres_hmo) + 1)

mujeres_pos_hmo = desap_mujeres_hmo.loc["HERMOSILLO"].loc["pos"]

#INDETERMINADOS
desap_indeterminados_hmo = desap_sonora_df.sort_values(by='Indeterminado', ascending=False, na_position='first')
desap_indeterminados_hmo['pos'] = range(1, len(desap_indeterminados_hmo) + 1)

indeterminados_pos_hmo = desap_indeterminados_hmo.loc["HERMOSILLO"].loc["pos"]

print("Lugar de Hombres Desaparecidos:\t" + str(hombres_pos_hmo))
print("Lugar de Mujeres Desaparecidas:\t" + str(mujeres_pos_hmo))
print("Lugar de Indeterminados Desaparecidos:\t" + str(indeterminados_pos_hmo))
# Out:
# Lugar de Hombres Desaparecidos:	1
# Lugar de Mujeres Desaparecidas:	1
# Lugar de Indeterminados Desaparecidos:	61

# %% [markdown]
# Ya que Hermosillo es el municpio con mayor población, los primeros dos lugares son de esperarse. Sin embargo, es notorio que caiga tan abajo en su posición de desaparecidos de sexo indeterminado. Sería interesanteun análisis de ello.

# %%
# 2do DataFrame: Periodistas Desaparecidos

# Podemos también ver cuantos periodistas desaparecieron en México. Este conjunto
# de datos no contiene muchos valores, lo cual se ejemplifica con los periodistas
# desaparecidos mensualmente por año.

with open("data/datos_procesados/por_categoria/periodista.json") as f:
  periodistas_json = json.load(f)

periodistas_df = pd.read_json(json.dumps(periodistas_json["mensual_ultimo_anio"], indent=4))

periodistas_df
# Out:
# <ipython-input-179-c3a10082b0d3>:10: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   periodistas_df = pd.read_json(json.dumps(periodistas_json["mensual_ultimo_anio"], indent=4))
#                 Hombre  Indeterminado  Mujer
# 2012-NOVIEMBRE       1              0      0
# 2020-FEBRERO         1              0      0
# 2020-NOVIEMBRE       0              0      1
# 2021-MARZO           2              0      0

# %%
# Podemos ver que, en total, solo hubo 5 periodistas desaparecidos registrados
# en los años 2012, 2020 y 2021.

# Veamos sus edades.

periodistas_df = pd.read_json(json.dumps(periodistas_json["por_edad"], indent=4))

periodistas_df
# Out:
# <ipython-input-180-623210266abf>:6: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   periodistas_df = pd.read_json(json.dumps(periodistas_json["por_edad"], indent=4))
# <ipython-input-180-623210266abf>:6: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   periodistas_df = pd.read_json(json.dumps(periodistas_json["por_edad"], indent=4))
# <ipython-input-180-623210266abf>:6: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   periodistas_df = pd.read_json(json.dumps(periodistas_json["por_edad"], indent=4))
# <ipython-input-180-623210266abf>:6: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   periodistas_df = pd.read_json(json.dumps(periodistas_json["por_edad"], indent=4))
#                         Hombres  Indeterminado  Mujeres
# 15                            0              0        1
# 24                            1              0        0
# 33                            1              0        0
# 37                            1              0        0
# SIN EDAD DE REFERENCIA        1              0        0

# %% [markdown]
# Debido a la poca cantidad de datos, no es posible obtener una conclusión con respecto a los periodistas desaparecidos.

# %%
# 3er DataFrame: Desaparecidos por Edades en Sonora

# Al buscar a los periodistas desaparecidos, fue interesante ver un conteo por
# edades. Por lo tanto, hagamos eso mismo pero para el conteo que teníamos en
# el estado de Sonora.

with open("data/datos_procesados/estados/26.json") as f:
  edades_json = json.load(f)

edades_df = pd.read_json(json.dumps(edades_json["por_edad"], indent=4))

edades_df
# Out:
# <ipython-input-181-d8433e3be8af>:10: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   edades_df = pd.read_json(json.dumps(edades_json["por_edad"], indent=4))
# <ipython-input-181-d8433e3be8af>:10: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   edades_df = pd.read_json(json.dumps(edades_json["por_edad"], indent=4))
# <ipython-input-181-d8433e3be8af>:10: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   edades_df = pd.read_json(json.dumps(edades_json["por_edad"], indent=4))
# <ipython-input-181-d8433e3be8af>:10: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   edades_df = pd.read_json(json.dumps(edades_json["por_edad"], indent=4))
#                         Hombres  Indeterminado  Mujeres
# 0                            73              0       73
# 1                             4              0        7
# 10                           14              0        4
# 11                            8              0       10
# 12                           27              0       43
# ...                         ...            ...      ...
# 9                             9              0        3
# 91                            1              0        0
# 92                            2              0        0
# 95                            1              0        0
# SIN EDAD DE REFERENCIA      757              2      485
#
# [91 rows x 3 columns]

# %%
# Veamos qué edades son las que más desaparecidos tienen para hombres, mujeres e
# indeterminados.

#HOMBRES
desap_hombres_hmo = edades_df.sort_values(by='Hombres', ascending=False, na_position='first')
desap_hombres_hmo['pos'] = range(1, len(desap_hombres_hmo) + 1)

desap_hombres_hmo[["Hombres", "pos"]]
# Out:
#                         Hombres  pos
# SIN EDAD DE REFERENCIA      757    1
# 25                          117    2
# 32                          114    3
# 30                          109    4
# 29                          107    5
# ...                         ...  ...
# 84                            1   87
# 70                            1   88
# 91                            1   89
# 95                            1   90
# 83                            1   91
#
# [91 rows x 2 columns]

# %%
# Podemos ver que el primer lugar es para la gran cantidad de desaparecidos para
# quienes no se cuenta con registro de edad. Sin embargo, desde el 2do lugar, hasta
# el 5to lugar, son solo edades entre 25 y 32.

# Ahora, veamos las edades para las mujeres.

#MUJERES
desap_mujeres_hmo = edades_df.sort_values(by='Mujeres', ascending=False, na_position='first')
desap_mujeres_hmo['pos'] = range(1, len(desap_mujeres_hmo) + 1)

desap_mujeres_hmo[["Mujeres", "pos"]]
# Out:
#                         Mujeres  pos
# SIN EDAD DE REFERENCIA      485    1
# 14                          221    2
# 15                          209    3
# 16                          166    4
# 17                          120    5
# ...                         ...  ...
# 69                            0   87
# 78                            0   88
# 77                            0   89
# 70                            0   90
# 82                            0   91
#
# [91 rows x 2 columns]

# %%
# Al igual que en el caso de los hombres, el 1er lugar son las personas para quienes
# no hay edad de referencia. Sin embargo, del 2do al 5to lugar tenemos solo edades
# de entre 14 a 17 años.

# Finalmente, veamos para las personas de sexo indeterminado.

#INDETERMINADO
desap_indeterminado_hmo = edades_df.sort_values(by='Indeterminado', ascending=False, na_position='first')
desap_indeterminado_hmo['pos'] = range(1, len(desap_indeterminado_hmo) + 1)

desap_indeterminado_hmo[["Indeterminado", "pos"]]
# Out:
#                         Indeterminado  pos
# SIN EDAD DE REFERENCIA              2    1
# 25                                  2    2
# 54                                  1    3
# 27                                  1    4
# 31                                  1    5
# ...                               ...  ...
# 36                                  0   87
# 35                                  0   88
# 34                                  0   89
# 33                                  0   90
# 5                                   0   91
#
# [91 rows x 2 columns]

# %% [markdown]
# Aquí aunque tengamos de nuevo como 1er lugar a las personas para quienes no tenemos edad de referencia, el resto de lugares no parecen estar en un rango de edades especifico que nos haga notar algo en particular.

# %% [markdown]
# # 3. Archivos xml
#
# Los archivos *xml* son una manera de compartir información a través de internet o de guardar información con formatos genéricos que sigue siendo muy utilizada hoy en día. En general lidiar con archivos xml es una pesadilla y se necesita explorarlos con calma y revisarlos bien antes de usarlos.
#
# La definición del formato y su uso se puede revisar en [este tutorial de la w3schools](https://www.w3schools.com/xml/default.asp). Vamos a ver un ejemplo sencillo basado en la librería [xml.etree.ElementTree](https://docs.python.org/3/library/xml.etree.elementtree.html) que viene de base en python:

# %%
import xml.etree.ElementTree as et

archivo_url = "https://github.com/mcd-unison/ing-caract/raw/main/ejemplos/integracion/ejemplos/ejemplo.xml"
archivo_nombre = "ejemplito.xml"
subdir = "./data/"

if not os.path.exists(subdir + archivo_nombre):
    if not os.path.exists(subdir):
        os.makedirs(subdir)
    urllib.request.urlretrieve(archivo_url, subdir + archivo_nombre)


desayunos = et.parse(subdir + archivo_nombre)

for (i, des) in enumerate(desayunos.getroot()):
    print("Opción {}:".format(i+1))
    for prop in des:
        print("\t{}: {}".format(prop.tag, prop.text.strip()))

# Se puede buscar por etiquetas y subetiquetas

print("Los desayunos disponibles son: " +
      ", ".join([p.text for p in desayunos.findall("food/name")]))

# ¿Como se podría poner esta información en un DataFrame de `pandas`?
# Agreguen tanto código como consideren necesario.
# Out:
# Opción 1:
# 	name: Belgian Waffles
# 	price: $5.95
# 	description: Two of our famous Belgian Waffles with plenty of real maple syrup
# 	calories: 650
# Opción 2:
# 	name: Strawberry Belgian Waffles
# 	price: $7.95
# 	description: Light Belgian waffles covered with strawberries and whipped cream
# 	calories: 900
# Opción 3:
# 	name: Berry-Berry Belgian Waffles
# 	price: $8.95
# 	description: Belgian waffles covered with assorted fresh berries and whipped cream
# 	calories: 900
# Opción 4:
# 	name: French Toast
# 	price: $4.50
# 	description: Thick slices made from our homemade sourdough bread
# 	calories: 600
# Opción 5:
# 	name: Homestyle Breakfast
# 	price: $6.95
# 	description: Two eggs, bacon or sausage, toast, and our ever-popular hash browns
# 	calories: 950
# Los desayunos disponibles son: Belgian Waffles, Strawberry Belgian Waffles, Berry-Berry Belgian Waffles, French Toast, Homestyle Breakfast

# %% [markdown]
# Wikipedia es un buen ejemplo de un lugar donde la información se guarda y se descarga en forma de archivos xml. Por ejemplo, si queremos descargar datos de la wikipedia [con su herramienta de exportación en python](https://www.mediawiki.org/wiki/Manual:Pywikibot) utilizando [las categorias definidas por Wikipedia](https://es.wikipedia.org/wiki/Portal:Portada). Para hacerlo en forma programática es ecesario usar la [API de Mediawiki](https://github.com/mudroljub/wikipedia-api-docs) que veremos más adelante.
#
# Por el momento descargemos unos datos de *wikipedia* y hagamos el ejercicio de tratar de entender la estructura del árbol.

# %%
archivo_url = "https://github.com/mcd-unison/ing-caract/raw/main/ejemplos/integracion/ejemplos/wikipedia-poetas.xml"
archivo_nombre = "poetas.xml"
subdir = "./data/"

if not os.path.exists(subdir + archivo_nombre):
    if not os.path.exists(subdir):
        os.makedirs(subdir)
    urllib.request.urlretrieve(archivo_url, subdir + archivo_nombre)


poetas = et.parse(subdir + archivo_nombre)

# %% [markdown]
# ### Ejercicio
#
# Entender la estructura del archivo `xml` de poetas y generar un `DataFrame` con la información más importante. No olvides de comentar tu código y explicar la estructura del archivo `xml`

# %%
# Primero, podemos hacer un desglose de todos los poestas que tenemos de una manera
# similar al ejemplo anterior. Esto solo como un comienzo para tratar de darnos
# una idea de su estructura.

for (i, des) in enumerate(poetas.getroot()):
    print("Poeta {}:".format(i+1))
    for prop in des:
        print("\t {} : {}".format(prop.tag, prop.text.strip()))
# Out:
# Poeta 1:
# 	 {http://www.mediawiki.org/xml/export-0.10/}sitename : Wikipedia
# 	 {http://www.mediawiki.org/xml/export-0.10/}dbname : eswiki
# 	 {http://www.mediawiki.org/xml/export-0.10/}base : https://es.wikipedia.org/wiki/Wikipedia:Portada
# 	 {http://www.mediawiki.org/xml/export-0.10/}generator : MediaWiki 1.32.0-wmf.13
# 	 {http://www.mediawiki.org/xml/export-0.10/}case : first-letter
# 	 {http://www.mediawiki.org/xml/export-0.10/}namespaces :
# Poeta 2:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Julia Morilla de Campbell
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 4949229
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 3:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Luis Negreti
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 5105749
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 4:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Poldy Bird
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 4477192
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 5:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Ana María Shua
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 423422
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 6:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : León Benarós
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 4284479
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 7:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Alejandro González Gattone
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 5436786
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 8:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Silvia Schujer
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 3148146
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 9:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Laura Devetach
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 2428185
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 10:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Graciela Repún
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 1108758
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 11:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : María Cristina Ramos
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 3222523
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 12:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Olga Orozco
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 190419
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 13:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Luisa Valenzuela
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 859323
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 14:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Manuela Fingueret
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 5687611
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 15:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Javier Villafañe
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 2605282
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 16:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Santiago Kovadloff
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 538911
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 17:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Luis Landriscina
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 505969
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 18:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Tom Lupo
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 2703105
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 19:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Alicia Dujovne Ortiz
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 1905476
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 20:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Rosa Wernicke
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 5708383
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 21:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Ataliva Herrera
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 6059383
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 22:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Oche Califa
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 6069903
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 23:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Romualdo Brughetti
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 6102850
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 24:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Edith Mabel Russo
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 4455001
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 25:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Homero Manzi
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 131762
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 26:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Sergio de Castro (artista argentino)
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 6247653
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 27:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Adrián Abonizio
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 1922022
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 28:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Aníbal de Antón
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 6014210
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 29:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Domingo Zerpa
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 6321025
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 30:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Claudio Serra Brun
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 4290091
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 31:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Mario R. Vecchioli
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 6422174
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 32:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Zaki Konsol
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 6536346
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 33:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Carlos Juárez Aldazábal
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 5466763
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 34:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Héctor Gagliardi
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 1462230
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 35:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Paco Urondo
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 393274
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 36:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Celedonio Flores
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 1367048
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 37:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Enrique Banchs
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 104271
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 38:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Evaristo Carriego (poeta)
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 514987
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 39:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Alejandra Pizarnik
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 3528679
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 40:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Pedro Miguel Obligado
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 4987809
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 41:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Enrique Molina (poeta)
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 856852
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 42:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : César Tiempo
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 1520013
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 43:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Ricardo Güiraldes
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 441852
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 44:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Norah Lange
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 844590
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 45:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Macedonio Fernández
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 85863
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 46:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Juan Carlos Dávalos
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 2733201
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 47:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Carlos de la Púa
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 1868603
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 48:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Baldomero Fernández Moreno
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 433341
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 49:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Ricardo Molinari
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 2640247
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 50:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Rafael Squirru
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 990690
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 51:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Conrado Nalé Roxlo
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 356721
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 52:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Silvina Ocampo
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 282943
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 53:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Ezequiel Martínez Estrada
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 423873
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 54:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Antonio Esteban Agüero
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 5238553
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 55:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Esteban Abad
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 6318564
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 56:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Fernán Félix de Amador
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 6477898
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 57:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Mario Jorge de Lellis
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 4175608
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 58:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Julio Huasi
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 1864471
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 59:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Horacio Salas
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 5771379
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 60:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Roberto Hermida
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 4340157
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 61:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Alejandro Kurz
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 6451576
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 62:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Cayetano Córdova Iturburu
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 2558381
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 63:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Washington Cucurto
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 802919
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 64:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Aníbal Cristobo
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 2793206
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 65:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Humberto Costantini
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 281627
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 66:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Martín Coronado
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 1527691
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 67:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Astul Urquiaga
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 3075321
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 68:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Reynaldo Uribe
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 6145223
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 69:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Edgardo Dobry
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 2379112
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 70:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Libertad Demitrópulos
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 4587151
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 71:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Aníbal Cambas
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 5356461
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 72:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Daniel Omar Favero
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 4578838
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 73:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Eduardo Antonio Fracchia
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 4400037
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 74:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Hugo Foguet
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 903635
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 75:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Jacobo Feldman
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 2819076
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 76:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : C.E. Feiling
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 926811
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 77:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Fortunato Ramos
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 5938957
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 78:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Atilio Milanta
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 757375
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 79:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Julio Migno
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 2499714
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 80:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Jorge Méndez
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 1768426
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 81:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Higinio Mena
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 683838
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 82:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Graciela Maturo
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 6239963
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 83:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Carlos Mastronardi
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 1119010
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 84:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Linares Cardozo
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 2440430
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 85:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Arnaldo Calveyra
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 5789273
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 86:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Cachilo (poeta)
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 1804966
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 87:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Emma de Cartosio
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 1300166
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 88:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Gustavo Caso Rosendi
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 2185485
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 89:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Leopoldo Díaz Vélez
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 6408608
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 90:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Alejandro De Michele
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 317877
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 91:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Julio Domínguez
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 5294886
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 92:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Daniel Durand
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 2208932
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 93:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Máximo Orsi
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 6536259
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 94:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Tomás Braulio Platero
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 6301498
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 95:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Tamara Kamenszain
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 4110687
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 96:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Osvaldo Svanascini
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 6449998
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 97:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Alfredo Navarrine
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 6587242
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 98:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : María Negroni
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 4878910
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 99:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Alfredo Veiravé
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 5541592
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 100:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : María Antonia Zaragoza
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 6513511
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 101:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Mario Pablo Ortiz
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 5932282
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 102:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Leopoldo Díaz
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 6259009
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 103:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : José de Maturana
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 3131716
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 104:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Gastón Gori
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 473758
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 105:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : José Pedroni
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 417195
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 106:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Iris Pavón
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 4669654
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 107:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Raquel Partnoy
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 4874294
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 108:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Rogelio Pizzi
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 1546104
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 109:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Juan Emmanuel Ponce de León
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 2888719
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 110:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Ramón Ayala (cantante argentino)
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 3580983
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 111:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Hilario Cuadros
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 530834
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 112:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Alberto Cortez
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 826186
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 113:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Celia Correas de Zapata
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 4878867
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 114:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Gabino Coria Peñaloza
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 1805076
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 115:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Arturo Marasso
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 1405886
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 116:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Raúl Vera Ocampo
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 1301827
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 117:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Alberto Alba
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 2397751
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 118:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Cristóforo Juárez
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 6060677
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 119:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Anahí Lazzaroni
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 1956707
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 120:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : José María Castiñeira de Dios
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 666063
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 121:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Marcelo Berbel
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 232357
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 122:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Jorge Rojas (cantante)
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 2286129
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 123:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : José Antonio Abdelnur
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 1585430
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 124:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Javier Adúriz
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 36583
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 125:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Constante José Aguer
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 4115546
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 126:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Ángel de Estrada
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 2626161
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 127:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Jenny Wasiuk
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 6476359
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 128:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Margot Moreyra
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 6198099
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 129:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Daniel Muxica
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 2855319
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 130:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Héctor A. Murena
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 1461708
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 131:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Daniel Salzano
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 865784
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 132:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Jorge Sánchez Aguilar
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 2597091
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 133:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Andrés Cepeda (poeta)
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 6103552
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 134:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Jorge Ángel Livraga Rizzi
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 101933
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 135:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : José Ramón Luna
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 5984426
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 136:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Luis María Sobrón
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 2655412
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 137:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Carlos Pierre
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 646706
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 138:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Héctor A. Piccoli
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 5126936
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 139:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Ariel Petrocelli
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 2971233
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 140:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Mempo Giardinelli
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 255862
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 141:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Manuel J. Castilla
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 396114
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 142:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Joaquín Castellanos
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 2776269
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 143:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Diana Bellessi
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 707135
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 144:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Lito Bayardo
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 6094618
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 145:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Néstor Groppa
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 1156809
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 146:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Bernardo Verbitsky
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 49441
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 147:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Marcos Silber
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 2899488
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 148:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Luis Salvarezza
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 2889756
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 149:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Francisco López Merino
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 2296185
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 150:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Alfredo Julio Grassi
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 2393003
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 151:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Ana María Machado
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 1456705
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 152:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Claudio Martínez Paiva
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 5205178
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 153:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Marcelo Moreyra
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 5971707
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 154:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Rodolfo Alonso
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 3536059
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 155:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Apachaca
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 4675913
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 156:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Leopoldo Marechal
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 413682
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 157:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Carlos Schaefer Gallo
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 6171238
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 158:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Alfonsina Storni
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 3606921
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 159:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Leopoldo Lugones
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 64235
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 160:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Fernando Noy
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 6903613
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 161:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Milton Aguilar
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 6951511
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 162:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Raúl Rosarivo
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 6965127
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 163:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Vicente Muleiro
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 6978408
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 164:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Abel Rodríguez
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 6600791
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 165:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Oliverio Girondo
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 833311
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 166:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Paula Wajsman
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 5277199
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 167:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Aledo Meloni
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 1814201
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 168:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Ricardo Ernesto Montes i Bradley
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 1602693
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 169:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Eduardo Estévez
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 1974743
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 170:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : David Wapner
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 6071739
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 171:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Jorge Luis Borges
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 5674
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 172:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Alicia Borinsky
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 7331308
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 173:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Roberto Peregrino Salcedo
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 6213800
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 174:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Santiago Adamini
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 6299441
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 175:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Silverio Manco
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 6162446
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 176:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Julio José Leite
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 7497126
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 177:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Noni Benegas
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 5434117
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 178:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Mario Morales (poeta)
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 7478329
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 179:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Margarita Abella Caprile
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 3278754
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 180:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Oscar Sosa Ríos
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 6405827
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 181:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Julio Cortázar
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 9101
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 182:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Alfredo Carlino
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 5328848
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 183:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Leónidas Barletta
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 73433
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 184:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Jorge Beillard
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 6195034
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 185:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Luis Domingo Berho
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 6553602
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 186:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Francisco Luis Bernárdez
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 2317877
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 187:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Jorge Boccanera
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 842502
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 188:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Guillermo Boido
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 6033196
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 189:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Ángel Bonomini
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 5767980
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 190:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : José Antonio Bottiroli
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 4927884
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 191:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Carlos Alberto Brocato
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 5967470
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 192:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Juan Andrés Bruno
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 5596028
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 193:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Alfredo Bufano
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 874986
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# ...
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 2299696
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 578:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Gabriel Pérez Quitl
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 6061263
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 579:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Daniel Gutiérrez Pedreiro
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 4618722
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 580:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Elvira Quintana
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 7331051
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 581:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Alberto Paredes
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 7529458
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 582:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Martha Riva Palacio Obón
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 7588388
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 583:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Miréia Anieva
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 7587358
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 584:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Salvador Gallardo Cabrera
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 7618155
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 585:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Manuel de la Torre Lloreda
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 6856035
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 586:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Tecayehuatzin de Huexotzinco
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 7696565
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 587:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Francesca Gargallo
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 6643033
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 588:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Enriqueta Ochoa
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 6855332
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 589:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Nezahualpilli
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 165614
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 590:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Isaac Palacios Martínez
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 7821658
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 591:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Rebeca Uribe
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 7859815
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 592:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Camerina Pavón y Oviedo
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 6636198
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 593:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Josu Landa Goyogana
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 7886597
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 594:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Evodio Escalante Betancourt
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 7943533
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 595:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Juan Antonio Mateos
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 3232897
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 596:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Juan Rosas Talavera
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 7768559
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 597:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Raymundo Ramos
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 7808170
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 598:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Tania Favela
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 7659664
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 599:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Fabio Morábito
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 7828878
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 600:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Claudia Hernández de Valle Arizpe
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 7474100
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 601:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Carlos Eduardo Turón
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 8002327
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 602:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Tita Valencia
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 8003191
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 603:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Margarita Villaseñor
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 8003300
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 604:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Enrique González Rojo
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 8002917
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 605:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Marcela Solís-Quiroga
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 7848999
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 606:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Pablo Boullosa
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 7391830
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 607:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Antonio Delgado
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 8018327
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 608:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Daniel González Dueñas
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 8019612
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 609:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : José Martínez Torres
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 8019567
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 610:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : César Silva Márquez
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 8023745
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 611:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Simón de la Garza Melo
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 6239128
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 612:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Emiliano González (escritor)
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 8030487
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 613:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : José Guadalupe Velázquez (compositor)
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 7028049
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 614:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Juan Gregorio Regino
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 7943441
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 615:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Armida de la Vara
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 8041217
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 616:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Briceida Cuevas
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 7588025
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 617:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Christian Peña
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 6368777
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 618:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Esperanza Zambrano
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 7300628
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 619:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Jorge Humberto Chávez
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 6370378
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 620:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : José de Jesús Núñez y Domínguez
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 4412682
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 621:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Fernán González de Eslava
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 7846261
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 622:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Luis Mario Schneider
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 8017672
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 623:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Luis Ponce
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 4227334
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 624:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Sergio Mondragón
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 8004440
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 625:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Olivia de Montelongo
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 8184077
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 626:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Mauricio Siller Obregón
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 8200468
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 627:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Michel Juraidini
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 7703259
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 628:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Nirvana Paz
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 8327591
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 629:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Jorge Adalberto Vázquez
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 8345753
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 630:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Reneé Acosta
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 6127343
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 631:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : María Esther Nájera Arriaga
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 8391041
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 632:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Homero Acosta
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 8403363
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 633:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Marisol Patricia Rivas Castillo
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 8416823
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 634:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Ireneo Paz
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 2638518
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 635:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Juan B. Delgado
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 2930925
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 636:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Humberto Tejera
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 7887761
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 637:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Mario Molina Cruz
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 8440353
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 638:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Luis Ignacio Helguera
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 6449649
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 639:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Daniel Olivares Viniegra
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 8528770
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :
# Poeta 640:
# 	 {http://www.mediawiki.org/xml/export-0.10/}title : Guadalupe Flores Liera
# 	 {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# 	 {http://www.mediawiki.org/xml/export-0.10/}id : 8547651
# 	 {http://www.mediawiki.org/xml/export-0.10/}revision :

# %%
# Se trata entonces de una lista de poetas con su ID y todo un objeto de revisión.
# Podemos crear un DataFrame sencillo (ya que se trata de un ejercicio de ejemplo)
# para tener la información de cada poeta organizada.

# Primero importamos Numpy
import numpy as np

# Ahora, creamos un array vacío donde ir guardando los datos que saquemos de cada poeta.
data = []

# Ahora, iteramos sobre todos las subestructuras, las cuales ya sabemos son, casi
# todas, los poetas. Solo la primera tiene información sobre la pagina en sí.
for child in poetas.getroot():
  # Si la subestructura es "page", sabemos que tiene información de un poeta.
  if (child.tag == "{http://www.mediawiki.org/xml/export-0.10/}page"):
    # Primero, generamos un array para guardar el renglon de datos de un poeta.
    row = []

    # Luego, obtenemos la estructura del titulo, la cual es subestructura de "page".
    title = child.find("{http://www.mediawiki.org/xml/export-0.10/}title")
    # Agregamos el titulo como un dato al renglon.
    row.append(title.text.strip())

    # Hacemos exactamente lo mismo para el ID, ya que también es subestructura de "page".
    id = child.find("{http://www.mediawiki.org/xml/export-0.10/}id")
    row.append(id.text.strip())

    # Para el texto de la revisión es ligeramente distinto. Comenzamos obteniendo
    # la subestructura "revision".
    revision_parent = child.find("{http://www.mediawiki.org/xml/export-0.10/}revision")
    # El texto se encuentra en realidad en una estructura un nivel más abajo, llamada
    # "text". Sacamos ese texto y lo agregamos al renglon.
    revision_text = revision_parent.find("{http://www.mediawiki.org/xml/export-0.10/}text")
    row.append(revision_text.text.strip())

    # Ahora, agregamos ese renglon al array de datos.
    data.append(row)

# Convertimos el array a un array de Numpy.
np_data = np.array(data)
# Finalmente, convertimos los datos a un DataFrame.
poetas_df = pd.DataFrame({'ID': np_data[:, 1], 'Nombre': np_data[:, 0], 'Revisión': np_data[:, 2]})

poetas_df
# Out:
#           ID                     Nombre  \
# 0    4949229  Julia Morilla de Campbell
# 1    5105749               Luis Negreti
# 2    4477192                 Poldy Bird
# 3     423422             Ana María Shua
# 4    4284479               León Benarós
# ..       ...                        ...
# 634  7887761            Humberto Tejera
# 635  8440353          Mario Molina Cruz
# 636  6449649      Luis Ignacio Helguera
# 637  8528770   Daniel Olivares Viniegra
# 638  8547651     Guadalupe Flores Liera
#
#                                               Revisión
# 0    '''Julia Morilla de Campbell''' ([[Rosario (Ar...
# 1    {{Ficha de escritor\n|Imagen              = NE...
# 2    {{Ficha de persona\n| padres = Enrique Bird Mo...
# 3    {{Ficha de persona\n|imagen=\n|nombre de nacim...
# 4    {{Ficha de persona\n|nombre           = León B...
# ..                                                 ...
# 634  {{Ficha de persona\n| nombre = Humberto Tejera...
# 635  {{Ficha de escritor\n|nombre= Mario Molina Cru...
# 636  {{Ficha de persona\n| nombre = Luis Ignacio He...
# 637  {{Promocional|8|julio}}\n\n'''Daniel Olivares ...
# 638  '''Guadalupe Flores Liera''' (Ciudad de México...
#
# [639 rows x 3 columns]

# %% [markdown]
# # 4. Archivos de Excel
#
# Los archivos de excel son a veces nuestros mejores amigos, y otras veces nuestras peores pesadillas. Un archivo en excel (o cualquier otra hoja de caálculo) son formatos muy útiles que permiten compartir información técnica con personas sin preparación técnica, lo que lo vuelve una herramienta muy poderosa para comunicar hallazgos a los usuarios.
#
# Igualmente, la manipulación de datos a través de hojas de cálculo, sin usarlas correctamente 8esto es, programando cualquier modificación) genera normalmente un caos y una fuga de información importante para una posterior toma de desición.
#
# Como buena práctica, si se tiene acceso a la fuente primaria de datos y se puede uno evitar el uso de datos procesados en hoja de calculo, siempre es mejor esa alternativa (como científico de datos o analista de datos). Pero eso muchas veces es imposible.
#
# Vamos a dejar la importación desde `xlsx` a los cursos de *DataCamp* que lo tratan magistralmente. Es importante que, para que se pueda importar desde python o R, muchas veces es necesario instalar librerías extras.
